# %% [markdown]
# # Data Science Internship – Logic Building Task  6

# %% [markdown]
# #Problem 1: Smart Parking Lot Management System

# %%
def estimate_delivery_time(distance, traffic, weather):
    """
    Estimates delivery time dynamically.
    """
    base_time = distance * 5   # 5 minutes per km

    # Traffic adjustment
    if traffic == "High":
        base_time += 15
    elif traffic == "Medium":
        base_time += 8

    # Weather adjustment
    if weather == "Rainy":
        base_time += 10
    elif weather == "Storm":
        base_time += 20

    return base_time


# Example
eta = estimate_delivery_time(8, "High", "Rainy")
print("Estimated Delivery Time:", eta, "minutes")
# Out:
# Estimated Delivery Time: 65 minutes

# %% [markdown]
# # Problem 2: Online Food Delivery Time Estimator

# %%
def estimate_delivery_time(distance, traffic, weather):
    """
    Estimates delivery time dynamically.
    """
    base_time = distance * 5   # 5 minutes per km

    # Traffic adjustment
    if traffic == "High":
        base_time += 15
    elif traffic == "Medium":
        base_time += 8

    # Weather adjustment
    if weather == "Rainy":
        base_time += 10
    elif weather == "Storm":
        base_time += 20

    return base_time


# Example
eta = estimate_delivery_time(8, "High", "Rainy")
print("Estimated Delivery Time:", eta, "minutes")
# Out:
# Estimated Delivery Time: 65 minutes

# %% [markdown]
# # Problem 3: Movie Theatre Seat Occupancy Analyzer

# %%
def seat_occupancy(total_seats, booked_seats):
    """
    Calculates occupancy percentage and show status.
    """
    booked_count = len(booked_seats)
    occupancy = (booked_count / total_seats) * 100

    if occupancy == 100:
        status = "Housefull"
    elif occupancy >= 75:
        status = "Almost Full"
    else:
        status = "Seats Available"

    return occupancy, status


# Example
total = 200
booked = [1] * 150   # 150 seats booked
occupancy, status = seat_occupancy(total, booked)

print("Occupancy:", occupancy, "%")
print("Show Status:", status)
# Out:
# Occupancy: 75.0 %
# Show Status: Almost Full

# %% [markdown]
# # Problem 4: Cloud Server Load Classification System

# %%
def classify_server_load(cpu_readings):
    """
    Classifies server load based on average CPU usage.
    """
    total = 0

    for reading in cpu_readings:
        total += reading

    average = total / len(cpu_readings)

    if average < 50:
        status = "Normal"
    elif average <= 80:
        status = "Warning"
    else:
        status = "Critical"

    return average, status


# Example
cpu_data = [45, 60, 70, 85, 90]
avg_cpu, status = classify_server_load(cpu_data)

print("Average CPU Load:", avg_cpu, "%")
print("Server Status:", status)
# Out:
# Average CPU Load: 70.0 %
# Server Status: Warning

# %% [markdown]
# # Problem 5: Smart Classroom Resource Usage Monitor

# %%
def resource_monitor(resource_usage):
    """
    Identifies overused resources (>8 hours usage).
    """
    overused = []

    for resource, hours in resource_usage.items():
        if hours > 8:
            overused.append(resource)

    energy_alert = "Yes" if overused else "No"

    return overused, energy_alert


# Example
usage = {
    "Projector": 6,
    "AC": 9,
    "Lights": 4
}

overused, alert = resource_monitor(usage)

print("Overused Resources:", overused)
print("Energy Alert:", alert)
# Out:
# Overused Resources: ['AC']
# Energy Alert: Yes

# %% [markdown]
# # Problem 6: Online Event Registration Capacity Controller

# %%
def event_registration_controller(capacity, registrations):
    """
    Controls event registrations and prevents overbooking.
    """
    if registrations <= capacity:
        confirmed = registrations
        waitlisted = 0
        status = "Open"
    else:
        confirmed = capacity
        waitlisted = registrations - capacity
        status = "Closed"

    return confirmed, waitlisted, status


# Example
confirmed, waitlisted, status = event_registration_controller(100, 105)

print("Confirmed Registrations:", confirmed)
print("Waitlisted Users:", waitlisted)
print("Registration Status:", status)
# Out:
# Confirmed Registrations: 100
# Waitlisted Users: 5
# Registration Status: Closed
